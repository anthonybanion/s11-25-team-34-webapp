# %%
import pandas as pd
import numpy as np

# ---------------------------
# PRODUCT MOCK DATA (CLEAN)
# ---------------------------

data_products = {
    "id": list(range(1, 19)),

    "product": [
        'SilkBalance Emulsion', 'DeepRecover Emulsion', 'AquaDew Emulsion',
        'Calm Barrier Emulsion', 'RadiantSoft Emulsion', 'GreenBloom Emulsion',
        'Moisture Veil Emulsion', 'PureShield Emulsion', 'FreshGarden Cleanser',
        'SoftCloud Wash', 'Calming Leaf Cleanser', 'CitrusPurify Wash',
        'Avene Gentle Cleanser', 'EcoPure Soap Bar', 'Ocean Breeze Bar',
        'Lavender Bliss Soap', 'Coconut Dream Soap', 'Olive Balance Bar'
    ],

    "category": [
        'Emulsion']*8 + ['Cleanser']*5 + ['Soap']*5,

    "brand": [
        'SkinGlow', 'DermaCare', 'PureEssence', 'NatureLux', 'BioRadiance',
        'SkinGlow', 'DermaCare', 'PureEssence', 'NatureLux', 'BioRadiance',
        'SkinGlow', 'DermaCare', 'PureEssence', 'NatureLux', 'BioRadiance',
        'SkinGlow', 'DermaCare', 'PureEssence'
    ],

    # ingrediente principal para el eco-score
    "ingredient_main": [
        'Green Tea', 'Rice Extract','Niacinamide' , 'Oat Extract', 'Vitamin C',
        'Avocado Butter', 'Aloe Vera', 'Chamomile',
        'Thermal Water', 'Cucumber', 
        'Avocado Oil', 'Olive Oil', 'Shea Butter','Lavender Oil', 'Coconut Oil',
        'Lemon' , 'Centella Asiatica', 'Bamboo Extract'],

    # tipo → para lógica ambiental interna
    "base_type": [
        "water_based"]*5 +
        ["plant_based"]*3 +
        ["water_based"]*2 +
        ["oil_based"]*5 +
        ["plant_based"]*3,

    # categoría Climatiq
    "category_climatiq": [
        "consumer_goods-type_emulsion"]*8 +
        ["consumer_goods-type_facial_wash"]*5 +
        ["consumer_goods-type_soaps_and_cleaning_compounds"]*5,

    # packaging relevante
    "packaging_material": [
        'plastic_bottle']*4 + ['glass_container']*4 + ['plastic_tube']*5 + ['paper_wrap']*5,

    # pais de manufactura
    "origin_country": [
        'ARG','BRA','KOR','CHN','VNM','MEX','BRA','KOR',
        'ARG','ARG','CHN','VNM','MEX',
        'BRA','KOR','CHN','VNM','MEX'
    ],

    # variables Climatiq
    "money": [
        15.99,18.49,12.75,14.30,20.00,16.50,19.99,13.45,
        10.99,11.50,9.75,12.00,14.20,
        5.99,6.49,7.25,8.00,6.75
    ],

    "money_unit": ["USD"]*18,

    "weight": [
        150,200,120,180,220,160,210,130,
        100,110,90,115,140,
        80,85,95,105,88
    ],

    "weight_unit": ["g"]*18,

    # volumen solo para emulsiones
    "volume": [150,200,120,180,220,160,210,130] + [np.nan]*10,

    "volume_unit": ["ml"]*8 + [np.nan]*10,

    # reciclaje: más justo
    "recyclable_packaging": [
        True]*13 + [False]*5,

    "transportation_type": [
        'sea','air','sea','land','air','sea','land','air',
        'sea','land','air','sea','land',
        'air','sea','land','air','sea'
    ]
}

df_products = pd.DataFrame(data_products)

df_products.to_csv("products.csv", index=False)
print(df_products)
# Out:
#     id                 product  category        brand    ingredient_main  \
# 0    1    SilkBalance Emulsion  Emulsion     SkinGlow          Green Tea
# 1    2    DeepRecover Emulsion  Emulsion    DermaCare       Rice Extract
# 2    3        AquaDew Emulsion  Emulsion  PureEssence        Niacinamide
# 3    4   Calm Barrier Emulsion  Emulsion    NatureLux        Oat Extract
# 4    5    RadiantSoft Emulsion  Emulsion  BioRadiance          Vitamin C
# 5    6     GreenBloom Emulsion  Emulsion     SkinGlow     Avocado Butter
# 6    7  Moisture Veil Emulsion  Emulsion    DermaCare          Aloe Vera
# 7    8     PureShield Emulsion  Emulsion  PureEssence          Chamomile
# 8    9    FreshGarden Cleanser  Cleanser    NatureLux      Thermal Water
# 9   10          SoftCloud Wash  Cleanser  BioRadiance           Cucumber
# 10  11   Calming Leaf Cleanser  Cleanser     SkinGlow        Avocado Oil
# 11  12       CitrusPurify Wash  Cleanser    DermaCare          Olive Oil
# ...
